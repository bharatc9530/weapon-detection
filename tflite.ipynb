# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive 
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# 'Apriori Algorithm.ipynb'	        decision_tree.ipynb
#  Assignment-8.doc		       'Decision Tree _SLIQ_SPRINT.gslides'
#  Assignment-8.gdoc		        deepsort
# 'association rules updated.gslides'    'Getting started.pdf'
#  Bharat_Resume.pdf		        K-Means.ipynb
# 'classification_1 (1).gslides'	        Mall_Customers.csv
#  classification_1.gslides	       'My Drive'
#  Classroom			       'sentiment analysis'
# 'Colab Notebooks'		        yolo
# 'DBSCAN Algorithm from Scratch.ipynb'

# %%
# cd back into the darknet folder to run detections
# %cd /mydrive/yolo/yolov4/tflite/
# Out:
# /content/gdrive/My Drive/yolo/yolov4/tflite

# %%
pwd
# Out:
# '/content/gdrive/My Drive/yolo/yolov4/tflite'

# %%
# !git clone https://github.com/theAIGuysCode/tensorflow-yolov4-tflite.git
# Out:
# Cloning into 'tensorflow-yolov4-tflite'...
# remote: Enumerating objects: 907, done.
# remote: Total 907 (delta 0), reused 0 (delta 0), pack-reused 907
# Receiving objects: 100% (907/907), 211.45 MiB | 17.98 MiB/s, done.
# Resolving deltas: 100% (438/438), done.
# Checking out files: 100% (133/133), done.

# %%
ls
# Out:
# tensorflow-yolov4-tflite/

# %%
cd tensorflow-yolov4-tflite/
# Out:
# /content/gdrive/My Drive/yolo/yolov4/tflite/tensorflow-yolov4-tflite

# %%
cp /mydrive/yolo/yolov4/darknet/backup/yolov4-tiny_3000.weights /mydrive/yolo/yolov4/tflite/tensorflow-yolov4-tflite/data/

# %%
cp /mydrive/yolo/yolov4/darknet/training/obj.names /mydrive/yolo/yolov4/tflite/tensorflow-yolov4-tflite/data/classes/

# %%
# Save tf model for tflite converting
# !python save_model.py --weights ./data/yolov4-tiny_3000.weights --output ./checkpoints/yolov4-tiny-416 --input_size 416 --model yolov4 --tiny
# Out:
# 2020-10-15 06:14:09.264513: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-15 06:14:11.007933: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-15 06:14:11.043748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-15 06:14:11.044551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-15 06:14:11.044603: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# convert custom yolov4 tflite model
# !python convert_tflite.py --weights ./checkpoints/yolov4-tiny-416 --output ./checkpoints/custom-416.tflite
# Out:
# 2020-10-15 06:25:25.611500: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-15 06:25:27.002978: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-15 06:25:27.039200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-15 06:25:27.039817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-15 06:25:27.039858: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# Run custom tflite model
# !python detect.py --weights ./checkpoints/custom-416.tflite --size 416 --model yolov4 --images ./data/images/car.jpg --framework tflite
# Out:
# 2020-10-15 06:26:30.475515: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-15 06:26:31.845514: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-15 06:26:31.879494: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-15 06:26:31.880116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-15 06:26:31.880160: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !cp ./checkpoints/custom-416.tflite /mydrive/yolo/yolov4/darknet/backup/
